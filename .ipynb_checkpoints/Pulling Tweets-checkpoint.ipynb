# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\dell\miniconda3\envs\python\lib\site-packages (4.15.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from tweepy) (2.32.3)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dell\miniconda3\envs\python\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\miniconda3\envs\python\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import tweepy
import json

# Replace with your actual Bearer Token from developer.x.com
bearer_token = "AAAAAAAAAAAAAAAAAAAAABX60wEAAAAAfoY5SEQGqPSTyZu4u5TLfRsevcA%3DIGacIgwvC8CR0UsmRVeT8aFhTehLS1UclTqCTzWx9ezyqSePof"

# Initialize the Tweepy client
client = tweepy.Client(bearer_token=bearer_token)

# Define a simple query (you can customize this)
query = "(banjir OR flood OR earthquake OR gempa OR tsunami OR landslide OR haze OR storm OR typhoon OR tornado OR disaster OR emergency OR rescue OR evacuate) (Malaysia OR KL OR Selangor OR Johor OR Penang OR Sabah OR Sarawak OR Kedah OR Kelantan OR Perlis OR Perak OR Putrajaya OR Negeri Sembilan OR Melaka OR Terengganu OR Pahang) -is:retweet lang:en"


# Send request
response = client.search_recent_tweets(
    query=query,
    max_results=10,  # Max 100 if needed
    tweet_fields=["created_at", "text", "author_id", "public_metrics"]
)

# Print raw JSON for each tweet
if response.data:
    for tweet in response.data:
        raw_data = tweet.data  # Raw dict of the tweet
        print(json.dumps(raw_data, indent=2))  # Pretty print
else:
    print("No tweets found.")
# Out:
# {
#   "text": "There was an earthquake with a magnitude of 4.2 in K\u00fctahya Simav. #earthquake https://t.co/aHO99tdCbX",
#   "author_id": "1839800494958563328",
#   "created_at": "2025-05-02T13:57:05.000Z",
#   "public_metrics": {
#     "retweet_count": 0,
#     "reply_count": 0,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 191
#   },
#   "edit_history_tweet_ids": [
#     "1918303735115333777"
#   ],
#   "id": "1918303735115333777"
# }
# {
#   "text": "@alon_mizrahi Malaysia sent medical tents, aid &amp; immediate rescue team to Myanmar just hours after earthquake although it's a state hostile to Muslims. It can be done bcs none of the neighbouring leaders are puppets installed by the West.  &gt;10x aid for Gaza too but puppets close borders.",
#   "author_id": "713511516",
#   "created_at": "2025-05-02T13:39:39.000Z",
#   "public_metrics": {
#     "retweet_count": 0,
#     "reply_count": 0,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 130
#   },
#   "edit_history_tweet_ids": [
#     "1918299349022654558"
#   ],
#   "id": "1918299349022654558"
# }
# {
#   "text": "Finally ah. \n\nAfter that disaster in 2021 vs Malaysia, then also that disaster in group stage in 2023, becoming runner up, and has to meet China early, we finally got a medal. https://t.co/PkXHVV13sf",
#   "author_id": "1912875905325903872",
#   "created_at": "2025-05-02T13:35:14.000Z",
#   "public_metrics": {
#     "retweet_count": 0,
#     "reply_count": 0,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 10
#   },
#   "edit_history_tweet_ids": [
#     "1918298236336652468"
#   ],
#   "id": "1918298236336652468"
# }
# {
#   "text": "[02.05.2025 - 15:58:33] 7.5 magnitude earthquake occurred in  USHUAIA, ARGENTINA region  (Source: USGS) You can download the app for details: https://t.co/8VzJUSAbwi https://t.co/jZTWgzMEW2",
#   "author_id": "1084924405313093632",
#   "created_at": "2025-05-02T13:12:43.000Z",
#   "public_metrics": {
#     "retweet_count": 1,
#     "reply_count": 0,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 184
#   },
#   "edit_history_tweet_ids": [
#     "1918292570016264599"
#   ],
#   "id": "1918292570016264599"
# }
# {
#   "text": "[Malaysia] Residents scramble as flash floods threaten homes in Siburan\u2019s Taman Sentah Indah https://t.co/OGYQSvSoZB via #ClimateChange #ClimateCrisis #SevereWeather #Storm #Flood #TamanSentahIndah #Siburan #Sarawak #Malaysia",
#   "author_id": "1675807236164050944",
#   "created_at": "2025-05-02T11:22:32.000Z",
#   "public_metrics": {
#     "retweet_count": 0,
#     "reply_count": 0,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 21
#   },
#   "edit_history_tweet_ids": [
#     "1918264841141194941"
#   ],
#   "id": "1918264841141194941"
# }
# {
#   "text": "Nadin Amizah Malam Mendengar\n\n1 ticket to sell \n1x tix sorai (standing)\nRM 240 (np:258 incl service tax)\nReason: need to balik sabah emergency https://t.co/NJpgi2gKBC",
#   "author_id": "1041421255126114304",
#   "created_at": "2025-05-02T10:32:44.000Z",
#   "public_metrics": {
#     "retweet_count": 1,
#     "reply_count": 0,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 23
#   },
#   "edit_history_tweet_ids": [
#     "1918252307067838515"
#   ],
#   "id": "1918252307067838515"
# }
# {
#   "text": "@xdidiandrax WTS\nNadin Amizah Malam Mendengar \n1x tix sorai (standing)\nrm 240 (np:258 incl service tax)\nReason: emergency need to balik sabah",
#   "author_id": "1041421255126114304",
#   "created_at": "2025-05-02T10:31:21.000Z",
#   "public_metrics": {
#     "retweet_count": 0,
#     "reply_count": 0,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 16
#   },
#   "edit_history_tweet_ids": [
#     "1918251962782630150"
#   ],
#   "id": "1918251962782630150"
# }
# {
#   "text": "\ud83d\udea8 Flash flood alert in Siburan!\n\nHeavy rain since 3.30pm caused rising waters at Lorong 6, Taman Sentah Indah. Residents scrambled to move cars to higher ground. Water above ankle level but no homes affected yet.\nhttps://t.co/zyEGCbZPFj\n\n#Siburan #FlashFlood #Sarawak #Weather https://t.co/hF5JMKN7Dk",
#   "author_id": "153733343",
#   "created_at": "2025-05-02T10:17:50.000Z",
#   "public_metrics": {
#     "retweet_count": 0,
#     "reply_count": 0,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 83
#   },
#   "edit_history_tweet_ids": [
#     "1918248559532752954"
#   ],
#   "id": "1918248559532752954"
# }
# {
#   "text": "The Supreme Leader of the Democratic People's Republic of Malaya is in the Southern State of Johor prepping for Confrontation 2.0\n\nNapoleon says that an army fights on its stomach. That is why, in order to rescue Singapore and reunite it with Mainland, good food is a must! https://t.co/c6M9DZHqxH",
#   "author_id": "1369194262009540615",
#   "created_at": "2025-05-02T09:29:13.000Z",
#   "public_metrics": {
#     "retweet_count": 1,
#     "reply_count": 0,
#     "like_count": 12,
#     "quote_count": 2,
#     "bookmark_count": 0,
#     "impression_count": 680
#   },
#   "edit_history_tweet_ids": [
#     "1918236324093731102"
#   ],
#   "id": "1918236324093731102"
# }
# {
#   "text": "@adith2194 No premier,TF, raid,hit and  kl la thudrum storm ,",
#   "author_id": "1140319424232091649",
#   "created_at": "2025-05-02T07:49:03.000Z",
#   "public_metrics": {
#     "retweet_count": 0,
#     "reply_count": 1,
#     "like_count": 0,
#     "quote_count": 0,
#     "bookmark_count": 0,
#     "impression_count": 16
#   },
#   "edit_history_tweet_ids": [
#     "1918211115281977642"
#   ],
#   "id": "1918211115281977642"
# }
